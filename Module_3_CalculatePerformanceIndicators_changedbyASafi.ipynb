# %% [markdown]
# ## Module 3 - In this jupyter notebook, perfomance indicators are calculated
# * Step 3a - Set up: Import modules/libraries, inport data, create output folder
# * Step 3b - Calculate uniformity
# * Step 3c - Calculate efficiency (beneficial fraction)
# * Step 3d - Calculate adquacy
# * Step 3e - Calculate relative water deficit
# **=====================================================================================================================**
#
# ![title](img/Fig3_1.png)
#
# **=====================================================================================================================**
# #### <span style='background :lightgreen' > References:
# * Karimi, P., Bongani, B., Blatchford, M., and de Fraiture, C.: Global satellite-based ET products for the local level irrigation management: An application of irrigation performance assessment in the sugarbelt of Swaziland, Remote Sensing, 11, 705, 2019.
# * Bastiaanssen, W. G., and Bos, M.: Irrigation performance indicators based on remotely sensed data: a review of literature, Irrigation and drainage systems, 13, 291-311, 1999.
# * Bastiaanssen, W. G., Van der Wal, T., and Visser, T.: Diagnosis of regional evaporation by remote sensing to support irrigation performance assessment, Irrigation and Drainage Systems, 10, 1-23, 1996.

# %% [markdown]
# ## Step 3a - Set up

# %% [markdown]
# ## i) Import packages/libraries

# %%
import os
import sys
import glob

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# change the directory to where the modules are saved
os.chdir(os.path.join(os.path.split(os.getcwd())[0], "Modules"))
from GIS_functions import GIS_function as gis

# %% [markdown]
# ## ii) Import the input data
# * Seasonal T, AETI, ETp

# %%
# get seasonal data
#T_fhs    = glob.glob(r'..\Data\2L2_T_season\*.tif')
T_fhs    = glob.glob(r'C:\DATA\eLEAF\WaPOR\Gezira\Data Compoenets\T\*.tif')
#AETI_fhs = glob.glob(r'..\Data\2L2_AETI_season\*.tif')
AETI_fhs = glob.glob(r'C:\DATA\eLEAF\WaPOR\Gezira\Data Compoenets\AETI\*.tif')
ETp_fhs  = glob.glob(r'..\Data\2L1_ETp_season\*.tif')

# %% [markdown]
# ## iii) Output folder: Make one or connect to the existing one

# %%
# output_folder
#output_folderBF = r'..\Data\Results\3_BeneficialFraction'  # create output folder
output_folderBF = r'..\Data\Results\3_BeneficialFraction' 
output_folderAd = r'..\Data\Results\3_Adequacy'  # create output folder
output_folderCWD = r'..\Data\Results\3_CWD'  # create output folder

# Make one if the folder does not exit
if not os.path.exists(output_folderBF):
    os.makedirs(output_folderBF)
if not os.path.exists(output_folderAd):
    os.makedirs(output_folderAd)
if not os.path.exists(output_folderCWD):
    os.makedirs(output_folderCWD)

# %% [markdown]
# ## Step 3b - Calculate uniformity of water consumption
# * Equity is defined as the coefficients of variation (CV) of seasonal ETa in the area of interest.
# * It measures the evenness of the water supply in an irrigation scheme.
# * Note: CV of 0 to 10% is good, 10 to 25% is fair and CV > 25% is poor uniformity (Bastiaanssen et al., 1996)
# <br/>

# %%
# Uniformity of water Consumption 
# get seasonal AETI
# AETI_fhs = glob.glob(r'..\Data\2L2_AETI_season\*.tif') 

for i in range(len(AETI_fhs)):
    AETI = gis.OpenAsArray(AETI_fhs[i], nan_values=True)
    
    AETIm   = np.nanmean(AETI)
    AETIsd  = np.nanstd(AETI)
    
    CV_AETI = (AETIsd / AETIm) * 100
    
    # Identify the date from the file name
    date  = os.path.basename(AETI_fhs[i]).split('.')[0].replace('AETI', '').replace('_', ' ') 
    
    if CV_AETI < 10:
        U = 'Good Uniformity'
    if (CV_AETI >= 10) and (CV_AETI < 25):
        U = 'Fair Uniformity'
    else: 
        U = 'Poor Uniformity'

    print ('CV of AETI in', date, '=', round(CV_AETI, 1), ',', U)
# Out:
# CV of AETI in L3 GEZ  2101 = 64.3 , Poor Uniformity
# CV of AETI in L3 GEZ  2102 = 70.2 , Poor Uniformity
# CV of AETI in L3 GEZ  2103 = 70.2 , Poor Uniformity
# CV of AETI in L3 GEZ  2104 = 71.7 , Poor Uniformity
# CV of AETI in L3 GEZ  2105 = 73.9 , Poor Uniformity
# CV of AETI in L3 GEZ  2106 = 74.7 , Poor Uniformity
# CV of AETI in L3 GEZ  2107 = 72.8 , Poor Uniformity
# CV of AETI in L3 GEZ  2108 = 70.5 , Poor Uniformity
# CV of AETI in L3 GEZ  2109 = 73.1 , Poor Uniformity
# CV of AETI in L3 GEZ  2110 = 76.3 , Poor Uniformity
# CV of AETI in L3 GEZ  2111 = 77.9 , Poor Uniformity
# CV of AETI in L3 GEZ  2112 = 73.7 , Poor Uniformity
# CV of AETI in L3 GEZ  2113 = 77.9 , Poor Uniformity
# CV of AETI in L3 GEZ  2114 = 76.5 , Poor Uniformity
# CV of AETI in L3 GEZ  2115 = 74.2 , Poor Uniformity
# CV of AETI in L3 GEZ  2116 = 71.1 , Poor Uniformity
# CV of AETI in L3 GEZ  2117 = 74.6 , Poor Uniformity

# %% [markdown]
# ## Step 3c - Calculate efficiency (beneficial fraction)
# * Beneficial fraction is the ratio of the water that is consumed as transpiration compared to overall field water consumption (ETa).
# * $Beneficial fraction = \frac{T_a}{ET_a}$
# * It is a measure of the efficiency of on farm water and agronomic practices in use of water for crop growth.

# %%
# collecting Geoinfo such as projection, the x and y axis
in_fh = AETI_fhs[0]      
driver, NDV, xsize, ysize, GeoT, Projection = gis.GetGeoInfo(in_fh)
spatial_extent = (GeoT[0], GeoT[0] + GeoT[1] * xsize, GeoT[3] + GeoT[5] * ysize, GeoT[3])  # get spatial extent of raster
  
for Tfh, ETfh in zip(T_fhs, AETI_fhs):
    T    = gis.OpenAsArray(Tfh,  nan_values=True)
    AETI = gis.OpenAsArray(ETfh, nan_values=True)
    
    T_over_AETI = T/AETI
    
    T_over_AETI_mean = np.nanmean(T_over_AETI)
    AETI_mean = np.nanmean(AETI)
    T_mean = np.nanmean(T)
    
    # Identify the date from the file name
    date  = os.path.basename(ETfh).split('.')[0].replace('AETI', '').replace('_', ' ') 
    
    #print ('Beneficial Fraction', date, '=', round(AETI_mean, 2))
    print ('BF, AETI, T respectivly of ', date, '=', 'Are', round(T_over_AETI_mean, 2), round(AETI_mean, 2), round(T_mean, 2))
    
    #update the file name, and save into output folder
    #basename  = os.path.basename(ETfh).replace('AETI', 'BF')  
    #output_fn = os.path.join(output_folderBF, basename)
    #gis.CreateGeoTiff(output_fn, T_over_AETI, driver, NDV, xsize, ysize, GeoT, Projection) 
    
    # Plot the raster map
    #seasonal = T_over_AETI
    
    #plt.figure(figsize = (12,8))
    #plt.imshow(seasonal, cmap='RdYlGn', vmin=np.nanmin(seasonal), vmax=np.nanmax(seasonal), extent=spatial_extent)
    #plt.colorbar(shrink=0.75, label='BF [-]')
    #plt.xlabel('Longitude ($^{\circ}$ East)', fontsize=14)  # add axes label
    #plt.ylabel('Latitude ($^{\circ}$ North)', fontsize=14)
    #plt.title('Beneficial fraction [-] ' + date)
    #plt.clim(0,1)
    #plt.show ()
# Out:
# BF, AETI, T respectivly of  L3 GEZ  1001 = Are 0.67 34.43 24.27
# BF, AETI, T respectivly of  L3 GEZ  1002 = Are 0.73 39.98 30.0
# BF, AETI, T respectivly of  L3 GEZ  1003 = Are 0.76 44.63 35.09
# C:\Users\Safi\.conda\envs\waterpip\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.
# BF, AETI, T respectivly of  L3 GEZ  1004 = Are 0.78 38.15 30.6
# BF, AETI, T respectivly of  L3 GEZ  1005 = Are 0.71 39.38 29.79
# BF, AETI, T respectivly of  L3 GEZ  1006 = Are 0.63 26.92 19.52
# BF, AETI, T respectivly of  L3 GEZ  1007 = Are 0.59 30.5 20.9
# BF, AETI, T respectivly of  L3 GEZ  1008 = Are 0.55 28.58 18.22
# BF, AETI, T respectivly of  L3 GEZ  1009 = Are 0.61 29.07 19.09
# BF, AETI, T respectivly of  L3 GEZ  1010 = Are 0.54 24.1 13.92
# BF, AETI, T respectivly of  L3 GEZ  1011 = Are 0.5 16.88 9.02
# BF, AETI, T respectivly of  L3 GEZ  1012 = Are 0.44 19.4 8.98
# BF, AETI, T respectivly of  L3 GEZ  1013 = Are 0.39 20.4 8.45
# BF, AETI, T respectivly of  L3 GEZ  1014 = Are 0.36 15.04 5.67
# BF, AETI, T respectivly of  L3 GEZ  1015 = Are 0.28 18.9 5.66
# BF, AETI, T respectivly of  L3 GEZ  1016 = Are 0.25 19.93 5.22
# BF, AETI, T respectivly of  L3 GEZ  1017 = Are 0.18 23.38 4.36
# BF, AETI, T respectivly of  L3 GEZ  1018 = Are 0.22 21.31 4.82
# BF, AETI, T respectivly of  L3 GEZ  1019 = Are 0.35 21.12 7.75
# BF, AETI, T respectivly of  L3 GEZ  1020 = Are 0.46 14.16 6.91
# BF, AETI, T respectivly of  L3 GEZ  1021 = Are 0.49 23.08 11.98
# BF, AETI, T respectivly of  L3 GEZ  1022 = Are 0.57 26.64 16.15
# BF, AETI, T respectivly of  L3 GEZ  1023 = Are 0.65 22.41 14.99
# BF, AETI, T respectivly of  L3 GEZ  1024 = Are 0.62 29.03 19.09
# BF, AETI, T respectivly of  L3 GEZ  1025 = Are 0.6 33.67 21.64
# BF, AETI, T respectivly of  L3 GEZ  1026 = Are 0.66 31.57 21.93
# BF, AETI, T respectivly of  L3 GEZ  1027 = Are 0.67 37.4 26.57
# BF, AETI, T respectivly of  L3 GEZ  1028 = Are 0.64 45.4 30.56
# BF, AETI, T respectivly of  L3 GEZ  1029 = Are 0.61 50.15 31.99
# BF, AETI, T respectivly of  L3 GEZ  1030 = Are 0.63 52.44 34.22
# BF, AETI, T respectivly of  L3 GEZ  1031 = Are 0.75 44.28 34.16
# BF, AETI, T respectivly of  L3 GEZ  1032 = Are 0.75 38.49 30.04
# BF, AETI, T respectivly of  L3 GEZ  1033 = Are 0.74 36.94 28.26
# BF, AETI, T respectivly of  L3 GEZ  1034 = Are 0.74 33.57 25.94
# BF, AETI, T respectivly of  L3 GEZ  1035 = Are 0.75 31.48 24.76
# BF, AETI, T respectivly of  L3 GEZ  1036 = Are 0.74 34.36 26.52
# BF, AETI, T respectivly of  L3 GEZ  1101 = Are 0.75 30.77 24.25
# BF, AETI, T respectivly of  L3 GEZ  1102 = Are 0.76 31.71 25.15
# BF, AETI, T respectivly of  L3 GEZ  1103 = Are 0.74 42.33 32.97
# BF, AETI, T respectivly of  L3 GEZ  1104 = Are 0.75 39.77 31.46
# BF, AETI, T respectivly of  L3 GEZ  1105 = Are 0.75 36.1 28.68
# BF, AETI, T respectivly of  L3 GEZ  1106 = Are 0.69 32.58 24.01
# BF, AETI, T respectivly of  L3 GEZ  1107 = Are 0.68 32.75 23.94
# BF, AETI, T respectivly of  L3 GEZ  1108 = Are 0.61 21.45 14.79
# BF, AETI, T respectivly of  L3 GEZ  1109 = Are 0.61 19.13 12.97
# BF, AETI, T respectivly of  L3 GEZ  1110 = Are 0.58 17.07 10.85
# BF, AETI, T respectivly of  L3 GEZ  1111 = Are 0.51 18.83 10.38
# BF, AETI, T respectivly of  L3 GEZ  1112 = Are 0.46 14.99 7.44
# BF, AETI, T respectivly of  L3 GEZ  1113 = Are 0.42 15.23 6.74
# BF, AETI, T respectivly of  L3 GEZ  1114 = Are 0.39 19.46 7.85
# BF, AETI, T respectivly of  L3 GEZ  1115 = Are 0.37 19.06 7.29
# BF, AETI, T respectivly of  L3 GEZ  1116 = Are 0.32 23.2 7.7
# BF, AETI, T respectivly of  L3 GEZ  1117 = Are 0.31 18.63 6.04
# BF, AETI, T respectivly of  L3 GEZ  1118 = Are 0.39 20.31 8.12
# BF, AETI, T respectivly of  L3 GEZ  1119 = Are 0.53 19.67 10.57
# BF, AETI, T respectivly of  L3 GEZ  1120 = Are 0.53 22.21 12.01
# BF, AETI, T respectivly of  L3 GEZ  1121 = Are 0.38 26.6 10.7
# BF, AETI, T respectivly of  L3 GEZ  1122 = Are 0.47 29.45 14.4
# BF, AETI, T respectivly of  L3 GEZ  1123 = Are 0.55 33.63 19.19
# BF, AETI, T respectivly of  L3 GEZ  1124 = Are 0.65 41.62 28.13
# BF, AETI, T respectivly of  L3 GEZ  1125 = Are 0.8 33.62 27.52
# BF, AETI, T respectivly of  L3 GEZ  1126 = Are 0.75 38.9 29.85
# BF, AETI, T respectivly of  L3 GEZ  1127 = Are 0.71 49.43 36.12
# BF, AETI, T respectivly of  L3 GEZ  1128 = Are 0.68 50.83 36.13
# BF, AETI, T respectivly of  L3 GEZ  1129 = Are 0.68 43.55 31.01
# BF, AETI, T respectivly of  L3 GEZ  1130 = Are 0.86 34.17 28.55
# BF, AETI, T respectivly of  L3 GEZ  1131 = Are 0.79 33.19 27.37
# BF, AETI, T respectivly of  L3 GEZ  1132 = Are 0.68 37.73 29.07
# BF, AETI, T respectivly of  L3 GEZ  1133 = Are 0.71 28.49 22.44
# BF, AETI, T respectivly of  L3 GEZ  1134 = Are 0.69 27.06 20.86
# BF, AETI, T respectivly of  L3 GEZ  1135 = Are 0.67 30.35 22.65
# BF, AETI, T respectivly of  L3 GEZ  1136 = Are 0.67 35.29 26.2
# BF, AETI, T respectivly of  L3 GEZ  1201 = Are 0.68 33.09 25.17
# BF, AETI, T respectivly of  L3 GEZ  1202 = Are 0.7 33.0 25.71
# BF, AETI, T respectivly of  L3 GEZ  1203 = Are 0.69 37.67 29.5
# BF, AETI, T respectivly of  L3 GEZ  1204 = Are 0.67 39.3 29.81
# BF, AETI, T respectivly of  L3 GEZ  1205 = Are 0.64 34.33 25.23
# BF, AETI, T respectivly of  L3 GEZ  1206 = Are 0.62 25.39 18.31
# BF, AETI, T respectivly of  L3 GEZ  1207 = Are 0.61 24.2 17.15
# BF, AETI, T respectivly of  L3 GEZ  1208 = Are 0.57 21.32 13.94
# BF, AETI, T respectivly of  L3 GEZ  1209 = Are 0.59 16.3 10.75
# BF, AETI, T respectivly of  L3 GEZ  1210 = Are 0.56 13.29 8.07
# BF, AETI, T respectivly of  L3 GEZ  1211 = Are 0.47 15.19 7.6
# BF, AETI, T respectivly of  L3 GEZ  1212 = Are 0.44 14.63 6.83
# BF, AETI, T respectivly of  L3 GEZ  1213 = Are 0.35 14.86 5.57
# BF, AETI, T respectivly of  L3 GEZ  1214 = Are 0.29 17.64 5.36
# BF, AETI, T respectivly of  L3 GEZ  1215 = Are 0.25 23.97 6.16
# BF, AETI, T respectivly of  L3 GEZ  1216 = Are 0.23 22.33 5.46
# BF, AETI, T respectivly of  L3 GEZ  1217 = Are 0.26 21.49 5.74
# BF, AETI, T respectivly of  L3 GEZ  1218 = Are 0.3 15.19 4.79
# BF, AETI, T respectivly of  L3 GEZ  1219 = Are 0.32 14.35 4.78
# BF, AETI, T respectivly of  L3 GEZ  1220 = Are 0.37 20.56 7.96
# BF, AETI, T respectivly of  L3 GEZ  1221 = Are 0.47 24.16 11.83
# BF, AETI, T respectivly of  L3 GEZ  1222 = Are 0.59 21.51 12.99
# BF, AETI, T respectivly of  L3 GEZ  1223 = Are 0.66 31.48 21.34
# BF, AETI, T respectivly of  L3 GEZ  1224 = Are 0.77 38.3 30.26
# BF, AETI, T respectivly of  L3 GEZ  1225 = Are 0.82 34.24 28.97
# BF, AETI, T respectivly of  L3 GEZ  1226 = Are 0.72 41.02 31.24
# BF, AETI, T respectivly of  L3 GEZ  1227 = Are 0.69 40.24 30.04
# BF, AETI, T respectivly of  L3 GEZ  1228 = Are 0.62 43.94 29.71
# BF, AETI, T respectivly of  L3 GEZ  1229 = Are 0.62 46.51 31.48
# BF, AETI, T respectivly of  L3 GEZ  1230 = Are 0.67 50.88 37.2
# BF, AETI, T respectivly of  L3 GEZ  1231 = Are 0.65 39.77 28.18
# BF, AETI, T respectivly of  L3 GEZ  1232 = Are 0.7 38.48 29.95
# BF, AETI, T respectivly of  L3 GEZ  1233 = Are 0.7 33.21 25.88
# BF, AETI, T respectivly of  L3 GEZ  1234 = Are 0.67 31.69 23.74
# BF, AETI, T respectivly of  L3 GEZ  1235 = Are 0.69 29.45 22.56
# BF, AETI, T respectivly of  L3 GEZ  1236 = Are 0.71 29.36 22.85
# BF, AETI, T respectivly of  L3 GEZ  1301 = Are 0.7 28.05 21.77
# BF, AETI, T respectivly of  L3 GEZ  1302 = Are 0.66 29.78 22.08
# BF, AETI, T respectivly of  L3 GEZ  1303 = Are 0.63 36.36 25.66
# BF, AETI, T respectivly of  L3 GEZ  1304 = Are 0.64 30.44 22.25
# BF, AETI, T respectivly of  L3 GEZ  1305 = Are 0.61 28.06 20.07
# BF, AETI, T respectivly of  L3 GEZ  1306 = Are 0.57 19.11 12.96
# BF, AETI, T respectivly of  L3 GEZ  1307 = Are 0.55 21.63 14.08
# BF, AETI, T respectivly of  L3 GEZ  1308 = Are 0.51 21.12 12.39
# BF, AETI, T respectivly of  L3 GEZ  1309 = Are 0.51 12.87 7.9
# BF, AETI, T respectivly of  L3 GEZ  1310 = Are 0.44 10.44 5.68
# BF, AETI, T respectivly of  L3 GEZ  1311 = Are 0.42 9.76 4.96
# BF, AETI, T respectivly of  L3 GEZ  1312 = Are 0.66 4.32 2.67
# BF, AETI, T respectivly of  L3 GEZ  1313 = Are 0.31 6.76 2.57
# BF, AETI, T respectivly of  L3 GEZ  1314 = Are 0.25 11.79 3.51
# BF, AETI, T respectivly of  L3 GEZ  1315 = Are 0.34 9.52 3.23
# BF, AETI, T respectivly of  L3 GEZ  1316 = Are 0.28 13.68 4.25
# BF, AETI, T respectivly of  L3 GEZ  1317 = Are 0.36 9.68 3.87
# BF, AETI, T respectivly of  L3 GEZ  1318 = Are 0.37 14.24 5.83
# BF, AETI, T respectivly of  L3 GEZ  1319 = Are 0.37 28.28 11.22
# BF, AETI, T respectivly of  L3 GEZ  1320 = Are 0.51 24.31 13.3
# BF, AETI, T respectivly of  L3 GEZ  1321 = Are 0.48 32.69 16.75
# BF, AETI, T respectivly of  L3 GEZ  1322 = Are 0.5 22.82 12.5
# BF, AETI, T respectivly of  L3 GEZ  1323 = Are 0.62 20.68 13.94
# BF, AETI, T respectivly of  L3 GEZ  1324 = Are 0.68 27.84 20.25
# BF, AETI, T respectivly of  L3 GEZ  1325 = Are 0.63 34.14 23.15
# BF, AETI, T respectivly of  L3 GEZ  1326 = Are 0.67 39.35 28.04
# BF, AETI, T respectivly of  L3 GEZ  1327 = Are 0.75 35.64 28.54
# BF, AETI, T respectivly of  L3 GEZ  1328 = Are 0.78 27.83 22.83
# BF, AETI, T respectivly of  L3 GEZ  1329 = Are 0.74 30.6 24.48
# BF, AETI, T respectivly of  L3 GEZ  1330 = Are 0.75 33.18 26.68
# BF, AETI, T respectivly of  L3 GEZ  1331 = Are 0.69 36.13 28.04
# BF, AETI, T respectivly of  L3 GEZ  1332 = Are 0.71 33.23 26.36
# BF, AETI, T respectivly of  L3 GEZ  1333 = Are 0.73 28.22 22.25
# BF, AETI, T respectivly of  L3 GEZ  1334 = Are 0.69 34.53 26.33
# BF, AETI, T respectivly of  L3 GEZ  1335 = Are 0.79 25.85 21.44
# BF, AETI, T respectivly of  L3 GEZ  1336 = Are 0.75 32.57 26.17
# BF, AETI, T respectivly of  L3 GEZ  1401 = Are 0.74 32.17 25.83
# BF, AETI, T respectivly of  L3 GEZ  1402 = Are 0.72 35.7 28.13
# BF, AETI, T respectivly of  L3 GEZ  1403 = Are 0.69 47.81 35.98
# BF, AETI, T respectivly of  L3 GEZ  1404 = Are 0.73 39.86 31.96
# BF, AETI, T respectivly of  L3 GEZ  1405 = Are 0.69 35.06 27.59
# BF, AETI, T respectivly of  L3 GEZ  1406 = Are 0.65 28.51 21.36
# BF, AETI, T respectivly of  L3 GEZ  1407 = Are 0.53 34.85 20.99
# BF, AETI, T respectivly of  L3 GEZ  1408 = Are 0.6 24.74 16.6
# BF, AETI, T respectivly of  L3 GEZ  1409 = Are 0.67 13.43 9.68
# BF, AETI, T respectivly of  L3 GEZ  1410 = Are 0.49 17.03 9.69
# BF, AETI, T respectivly of  L3 GEZ  1411 = Are 0.39 14.74 6.69
# BF, AETI, T respectivly of  L3 GEZ  1412 = Are 0.39 21.78 9.55
# BF, AETI, T respectivly of  L3 GEZ  1413 = Are 0.35 20.72 8.14
# BF, AETI, T respectivly of  L3 GEZ  1414 = Are 0.34 9.85 3.68
# BF, AETI, T respectivly of  L3 GEZ  1415 = Are 0.31 19.29 6.56
# BF, AETI, T respectivly of  L3 GEZ  1416 = Are 0.33 13.01 4.68
# BF, AETI, T respectivly of  L3 GEZ  1417 = Are 0.39 5.47 2.19
# BF, AETI, T respectivly of  L3 GEZ  1418 = Are 0.23 18.82 4.83
# BF, AETI, T respectivly of  L3 GEZ  1419 = Are 0.17 25.85 4.76
# BF, AETI, T respectivly of  L3 GEZ  1420 = Are 0.25 23.49 6.2
# BF, AETI, T respectivly of  L3 GEZ  1421 = Are 0.34 25.94 9.36
# BF, AETI, T respectivly of  L3 GEZ  1422 = Are 0.47 22.4 11.27
# BF, AETI, T respectivly of  L3 GEZ  1423 = Are 0.55 32.24 18.98
# BF, AETI, T respectivly of  L3 GEZ  1424 = Are 0.57 29.92 18.35
# BF, AETI, T respectivly of  L3 GEZ  1425 = Are 0.63 32.49 22.04
# BF, AETI, T respectivly of  L3 GEZ  1426 = Are 0.7 38.42 28.45
# BF, AETI, T respectivly of  L3 GEZ  1427 = Are 0.76 42.34 33.77
# BF, AETI, T respectivly of  L3 GEZ  1428 = Are 0.75 33.76 26.77
# BF, AETI, T respectivly of  L3 GEZ  1429 = Are 0.69 36.87 27.24
# BF, AETI, T respectivly of  L3 GEZ  1430 = Are 0.69 41.41 31.32
# BF, AETI, T respectivly of  L3 GEZ  1431 = Are 0.71 34.95 27.72
# BF, AETI, T respectivly of  L3 GEZ  1432 = Are 0.7 32.35 25.32
# BF, AETI, T respectivly of  L3 GEZ  1433 = Are 0.72 29.16 23.22
# BF, AETI, T respectivly of  L3 GEZ  1434 = Are 0.66 31.1 22.6
# BF, AETI, T respectivly of  L3 GEZ  1435 = Are 0.69 31.19 23.51
# BF, AETI, T respectivly of  L3 GEZ  1436 = Are 0.71 34.42 26.51
# BF, AETI, T respectivly of  L3 GEZ  1501 = Are 0.73 29.22 23.33
# BF, AETI, T respectivly of  L3 GEZ  1502 = Are 0.7 30.72 23.78
# BF, AETI, T respectivly of  L3 GEZ  1503 = Are 0.67 44.6 32.94
# BF, AETI, T respectivly of  L3 GEZ  1504 = Are 0.67 42.4 31.77
# BF, AETI, T respectivly of  L3 GEZ  1505 = Are 0.65 43.63 31.51
# BF, AETI, T respectivly of  L3 GEZ  1506 = Are 0.66 29.22 21.7
# BF, AETI, T respectivly of  L3 GEZ  1507 = Are 0.64 30.98 22.35
# BF, AETI, T respectivly of  L3 GEZ  1508 = Are 0.61 31.07 21.53
# BF, AETI, T respectivly of  L3 GEZ  1509 = Are 0.56 24.49 15.87
# BF, AETI, T respectivly of  L3 GEZ  1510 = Are 0.61 12.11 8.2
# BF, AETI, T respectivly of  L3 GEZ  1511 = Are 0.61 13.41 9.09
# BF, AETI, T respectivly of  L3 GEZ  1512 = Are 0.44 15.14 7.57
# BF, AETI, T respectivly of  L3 GEZ  1513 = Are 0.57 4.16 2.07
# BF, AETI, T respectivly of  L3 GEZ  1514 = Are 0.93 1.18 0.9
# BF, AETI, T respectivly of  L3 GEZ  1515 = Are 0.44 11.9 4.65
# BF, AETI, T respectivly of  L3 GEZ  1516 = Are 0.31 15.37 5.29
# BF, AETI, T respectivly of  L3 GEZ  1517 = Are 0.33 16.7 6.0
# BF, AETI, T respectivly of  L3 GEZ  1518 = Are 0.32 22.06 7.62
# BF, AETI, T respectivly of  L3 GEZ  1519 = Are 0.33 21.17 7.56
# BF, AETI, T respectivly of  L3 GEZ  1520 = Are 0.29 28.64 9.2
# BF, AETI, T respectivly of  L3 GEZ  1521 = Are 0.36 36.39 14.0
# BF, AETI, T respectivly of  L3 GEZ  1522 = Are 0.45 29.0 13.99
# BF, AETI, T respectivly of  L3 GEZ  1523 = Are 0.52 36.28 20.63
# BF, AETI, T respectivly of  L3 GEZ  1524 = Are 0.64 34.59 23.92
# BF, AETI, T respectivly of  L3 GEZ  1525 = Are 0.64 31.67 22.6
# BF, AETI, T respectivly of  L3 GEZ  1526 = Are 0.58 39.78 25.18
# BF, AETI, T respectivly of  L3 GEZ  1527 = Are 0.59 48.67 31.83
# BF, AETI, T respectivly of  L3 GEZ  1528 = Are 0.61 38.98 26.93
# BF, AETI, T respectivly of  L3 GEZ  1529 = Are 0.58 45.06 29.22
# BF, AETI, T respectivly of  L3 GEZ  1530 = Are 0.63 44.68 31.47
# BF, AETI, T respectivly of  L3 GEZ  1531 = Are 0.79 28.27 23.98
# BF, AETI, T respectivly of  L3 GEZ  1532 = Are 0.7 32.56 26.21
# BF, AETI, T respectivly of  L3 GEZ  1533 = Are 0.68 33.77 26.16
# BF, AETI, T respectivly of  L3 GEZ  1534 = Are 0.71 28.63 22.77
# BF, AETI, T respectivly of  L3 GEZ  1535 = Are 0.75 26.55 21.34
# BF, AETI, T respectivly of  L3 GEZ  1536 = Are 0.72 32.04 25.47
# BF, AETI, T respectivly of  L3 GEZ  1601 = Are 0.7 32.84 25.51
# BF, AETI, T respectivly of  L3 GEZ  1602 = Are 0.7 35.48 27.4
# BF, AETI, T respectivly of  L3 GEZ  1603 = Are 0.72 35.51 28.49
# BF, AETI, T respectivly of  L3 GEZ  1604 = Are 0.69 38.42 29.9
# BF, AETI, T respectivly of  L3 GEZ  1605 = Are 0.65 38.63 28.83
# BF, AETI, T respectivly of  L3 GEZ  1606 = Are 0.65 31.43 23.53
# BF, AETI, T respectivly of  L3 GEZ  1607 = Are 0.53 41.61 25.04
# BF, AETI, T respectivly of  L3 GEZ  1608 = Are 0.47 39.7 20.81
# BF, AETI, T respectivly of  L3 GEZ  1609 = Are 0.54 20.84 13.45
# BF, AETI, T respectivly of  L3 GEZ  1610 = Are 0.46 16.08 8.82
# BF, AETI, T respectivly of  L3 GEZ  1611 = Are 0.42 16.15 8.22
# BF, AETI, T respectivly of  L3 GEZ  1612 = Are 0.35 15.82 6.87
# BF, AETI, T respectivly of  L3 GEZ  1613 = Are 0.27 19.89 6.22
# BF, AETI, T respectivly of  L3 GEZ  1614 = Are 0.23 22.26 5.53
# BF, AETI, T respectivly of  L3 GEZ  1615 = Are 0.26 8.68 2.69
# BF, AETI, T respectivly of  L3 GEZ  1616 = Are 0.52 2.24 1.02
# BF, AETI, T respectivly of  L3 GEZ  1617 = Are 0.2 11.34 2.46
# BF, AETI, T respectivly of  L3 GEZ  1618 = Are 0.28 14.8 4.71
# BF, AETI, T respectivly of  L3 GEZ  1619 = Are 0.36 18.68 7.33
# BF, AETI, T respectivly of  L3 GEZ  1620 = Are 0.32 22.66 7.76
# BF, AETI, T respectivly of  L3 GEZ  1621 = Are 0.38 28.11 11.47
# BF, AETI, T respectivly of  L3 GEZ  1622 = Are 0.45 23.12 11.11
# BF, AETI, T respectivly of  L3 GEZ  1623 = Are 0.49 31.38 16.67
# BF, AETI, T respectivly of  L3 GEZ  1624 = Are 0.57 45.12 27.4
# BF, AETI, T respectivly of  L3 GEZ  1625 = Are 0.6 42.22 27.03
# BF, AETI, T respectivly of  L3 GEZ  1626 = Are 0.61 44.26 28.52
# BF, AETI, T respectivly of  L3 GEZ  1627 = Are 0.63 50.01 33.57
# BF, AETI, T respectivly of  L3 GEZ  1628 = Are 0.68 42.12 30.66
# BF, AETI, T respectivly of  L3 GEZ  1629 = Are 0.67 35.49 26.34
# BF, AETI, T respectivly of  L3 GEZ  1630 = Are 0.69 40.54 31.09
# BF, AETI, T respectivly of  L3 GEZ  1631 = Are 0.75 31.35 25.79
# BF, AETI, T respectivly of  L3 GEZ  1632 = Are 0.7 34.11 26.83
# BF, AETI, T respectivly of  L3 GEZ  1633 = Are 0.67 37.07 27.87
# BF, AETI, T respectivly of  L3 GEZ  1634 = Are 0.71 34.52 26.97
# BF, AETI, T respectivly of  L3 GEZ  1635 = Are 0.74 35.27 28.07
# BF, AETI, T respectivly of  L3 GEZ  1636 = Are 0.74 44.58 35.41
# BF, AETI, T respectivly of  L3 GEZ  1701 = Are 0.73 43.28 34.33
# BF, AETI, T respectivly of  L3 GEZ  1702 = Are 0.72 44.7 35.05
# BF, AETI, T respectivly of  L3 GEZ  1703 = Are 0.73 50.29 39.91
# BF, AETI, T respectivly of  L3 GEZ  1704 = Are 0.73 43.38 34.49
# BF, AETI, T respectivly of  L3 GEZ  1705 = Are 0.74 41.63 33.62
# BF, AETI, T respectivly of  L3 GEZ  1706 = Are 0.73 30.77 24.71
# BF, AETI, T respectivly of  L3 GEZ  1707 = Are 0.69 38.85 29.7
# BF, AETI, T respectivly of  L3 GEZ  1708 = Are 0.63 35.52 24.65
# BF, AETI, T respectivly of  L3 GEZ  1709 = Are 0.62 27.61 19.2
# BF, AETI, T respectivly of  L3 GEZ  1710 = Are 0.66 12.28 8.44
# BF, AETI, T respectivly of  L3 GEZ  1711 = Are 0.65 8.18 5.13
# BF, AETI, T respectivly of  L3 GEZ  1712 = Are 0.55 7.16 4.05
# BF, AETI, T respectivly of  L3 GEZ  1713 = Are 0.74 3.57 2.27
# BF, AETI, T respectivly of  L3 GEZ  1714 = Are 0.46 7.81 3.41
# BF, AETI, T respectivly of  L3 GEZ  1715 = Are 0.45 10.07 4.1
# BF, AETI, T respectivly of  L3 GEZ  1716 = Are 0.38 6.65 2.64
# BF, AETI, T respectivly of  L3 GEZ  1717 = Are 0.28 17.19 5.38
# BF, AETI, T respectivly of  L3 GEZ  1718 = Are 0.26 14.53 4.3
# BF, AETI, T respectivly of  L3 GEZ  1719 = Are 0.31 14.24 4.91
# BF, AETI, T respectivly of  L3 GEZ  1720 = Are 0.24 28.59 7.59
# BF, AETI, T respectivly of  L3 GEZ  1721 = Are 0.32 28.52 10.01
# BF, AETI, T respectivly of  L3 GEZ  1722 = Are 0.39 24.24 10.14
# BF, AETI, T respectivly of  L3 GEZ  1723 = Are 0.44 27.09 12.64
# BF, AETI, T respectivly of  L3 GEZ  1724 = Are 0.53 26.82 15.16
# BF, AETI, T respectivly of  L3 GEZ  1725 = Are 0.63 28.39 19.31
# BF, AETI, T respectivly of  L3 GEZ  1726 = Are 0.66 39.78 27.81
# BF, AETI, T respectivly of  L3 GEZ  1727 = Are 0.67 43.17 30.42
# BF, AETI, T respectivly of  L3 GEZ  1728 = Are 0.63 45.72 30.83
# BF, AETI, T respectivly of  L3 GEZ  1729 = Are 0.69 40.5 30.22
# BF, AETI, T respectivly of  L3 GEZ  1730 = Are 0.67 44.69 33.08
# BF, AETI, T respectivly of  L3 GEZ  1731 = Are 0.66 43.6 31.51
# BF, AETI, T respectivly of  L3 GEZ  1732 = Are 0.65 40.65 28.83
# BF, AETI, T respectivly of  L3 GEZ  1733 = Are 0.73 30.37 24.49
# BF, AETI, T respectivly of  L3 GEZ  1734 = Are 0.73 28.71 22.9
# BF, AETI, T respectivly of  L3 GEZ  1735 = Are 0.71 32.45 25.07
# BF, AETI, T respectivly of  L3 GEZ  1736 = Are 0.71 38.53 29.36
# BF, AETI, T respectivly of  L3 GEZ  1801 = Are 0.74 33.97 27.46
# BF, AETI, T respectivly of  L3 GEZ  1802 = Are 0.74 37.38 29.92
# BF, AETI, T respectivly of  L3 GEZ  1803 = Are 0.75 43.7 35.52
# BF, AETI, T respectivly of  L3 GEZ  1804 = Are 0.72 44.62 35.16
# BF, AETI, T respectivly of  L3 GEZ  1805 = Are 0.71 45.41 34.85
# BF, AETI, T respectivly of  L3 GEZ  1806 = Are 0.69 34.64 26.11
# BF, AETI, T respectivly of  L3 GEZ  1807 = Are 0.68 40.17 30.45
# BF, AETI, T respectivly of  L3 GEZ  1808 = Are 0.68 32.65 25.05
# BF, AETI, T respectivly of  L3 GEZ  1809 = Are 0.59 29.03 19.61
# BF, AETI, T respectivly of  L3 GEZ  1810 = Are 0.6 17.09 11.8
# BF, AETI, T respectivly of  L3 GEZ  1811 = Are 0.52 15.39 9.33
# BF, AETI, T respectivly of  L3 GEZ  1812 = Are 0.44 16.44 8.19
# BF, AETI, T respectivly of  L3 GEZ  1813 = Are 0.36 9.88 4.12
# BF, AETI, T respectivly of  L3 GEZ  1814 = Are 0.35 16.13 6.16
# BF, AETI, T respectivly of  L3 GEZ  1815 = Are 0.33 22.24 7.68
# BF, AETI, T respectivly of  L3 GEZ  1816 = Are 0.32 17.16 5.89
# BF, AETI, T respectivly of  L3 GEZ  1817 = Are 0.27 18.8 5.45
# BF, AETI, T respectivly of  L3 GEZ  1818 = Are 0.21 23.48 5.15
# BF, AETI, T respectivly of  L3 GEZ  1819 = Are 0.22 27.87 6.7
# BF, AETI, T respectivly of  L3 GEZ  1820 = Are 0.33 30.28 10.55
# BF, AETI, T respectivly of  L3 GEZ  1821 = Are 0.51 29.44 15.92
# BF, AETI, T respectivly of  L3 GEZ  1822 = Are 0.62 30.16 19.49
# BF, AETI, T respectivly of  L3 GEZ  1823 = Are 0.6 36.63 23.01
# BF, AETI, T respectivly of  L3 GEZ  1824 = Are 0.66 46.83 32.32
# BF, AETI, T respectivly of  L3 GEZ  1825 = Are 0.68 41.15 29.27
# BF, AETI, T respectivly of  L3 GEZ  1826 = Are 0.71 40.49 30.16
# BF, AETI, T respectivly of  L3 GEZ  1827 = Are 0.75 38.99 30.97
# BF, AETI, T respectivly of  L3 GEZ  1828 = Are 0.75 32.74 26.83
# BF, AETI, T respectivly of  L3 GEZ  1829 = Are 0.74 33.68 27.24
# BF, AETI, T respectivly of  L3 GEZ  1830 = Are 0.72 32.19 25.82
# BF, AETI, T respectivly of  L3 GEZ  1831 = Are 0.7 35.58 28.32
# BF, AETI, T respectivly of  L3 GEZ  1832 = Are 0.71 35.41 28.08
# BF, AETI, T respectivly of  L3 GEZ  1833 = Are 0.7 33.14 26.05
# BF, AETI, T respectivly of  L3 GEZ  1834 = Are 0.73 33.11 26.3
# BF, AETI, T respectivly of  L3 GEZ  1835 = Are 0.72 33.0 25.68
# BF, AETI, T respectivly of  L3 GEZ  1836 = Are 0.76 35.36 28.5
# BF, AETI, T respectivly of  L3 GEZ  1901 = Are 0.74 37.06 29.66
# BF, AETI, T respectivly of  L3 GEZ  1902 = Are 0.73 43.36 33.9
# BF, AETI, T respectivly of  L3 GEZ  1903 = Are 0.7 50.63 38.43
# BF, AETI, T respectivly of  L3 GEZ  1904 = Are 0.7 48.9 37.3
# BF, AETI, T respectivly of  L3 GEZ  1905 = Are 0.72 45.08 35.9
# BF, AETI, T respectivly of  L3 GEZ  1906 = Are 0.71 31.85 24.96
# BF, AETI, T respectivly of  L3 GEZ  1907 = Are 0.7 38.26 30.04
# BF, AETI, T respectivly of  L3 GEZ  1908 = Are 0.67 32.01 24.4
# BF, AETI, T respectivly of  L3 GEZ  1909 = Are 0.63 31.49 22.57
# BF, AETI, T respectivly of  L3 GEZ  1910 = Are 0.58 18.23 12.32
# BF, AETI, T respectivly of  L3 GEZ  1911 = Are 0.48 15.1 8.61
# BF, AETI, T respectivly of  L3 GEZ  1912 = Are 0.44 15.51 7.75
# BF, AETI, T respectivly of  L3 GEZ  1913 = Are 0.4 9.0 4.13
# BF, AETI, T respectivly of  L3 GEZ  1914 = Are 0.44 14.92 7.19
# BF, AETI, T respectivly of  L3 GEZ  1915 = Are 0.3 26.77 8.59
# BF, AETI, T respectivly of  L3 GEZ  1916 = Are 0.26 21.66 6.16
# BF, AETI, T respectivly of  L3 GEZ  1917 = Are 0.22 23.12 5.37
# BF, AETI, T respectivly of  L3 GEZ  1918 = Are 0.2 21.32 4.57
# BF, AETI, T respectivly of  L3 GEZ  1919 = Are 0.21 23.44 5.35
# BF, AETI, T respectivly of  L3 GEZ  1920 = Are 0.29 20.68 6.49
# BF, AETI, T respectivly of  L3 GEZ  1921 = Are 0.33 33.4 12.08
# BF, AETI, T respectivly of  L3 GEZ  1922 = Are 0.41 24.77 11.16
# BF, AETI, T respectivly of  L3 GEZ  1923 = Are 0.42 25.3 11.89
# BF, AETI, T respectivly of  L3 GEZ  1924 = Are 0.52 41.11 23.18
# BF, AETI, T respectivly of  L3 GEZ  1925 = Are 0.64 39.64 26.86
# BF, AETI, T respectivly of  L3 GEZ  1926 = Are 0.7 39.04 28.78
# BF, AETI, T respectivly of  L3 GEZ  1927 = Are 0.67 44.24 31.47
# BF, AETI, T respectivly of  L3 GEZ  1928 = Are 0.61 41.19 27.1
# BF, AETI, T respectivly of  L3 GEZ  1929 = Are 0.65 40.63 28.41
# BF, AETI, T respectivly of  L3 GEZ  1930 = Are 0.74 40.48 32.21
# BF, AETI, T respectivly of  L3 GEZ  1931 = Are 0.75 34.3 27.99
# BF, AETI, T respectivly of  L3 GEZ  1932 = Are 0.71 40.15 31.28
# BF, AETI, T respectivly of  L3 GEZ  1933 = Are 0.71 38.19 29.85
# BF, AETI, T respectivly of  L3 GEZ  1934 = Are 0.72 37.25 29.29
# BF, AETI, T respectivly of  L3 GEZ  1935 = Are 0.7 42.11 31.61
# BF, AETI, T respectivly of  L3 GEZ  1936 = Are 0.68 47.61 34.42
# BF, AETI, T respectivly of  L3 GEZ  2001 = Are 0.76 40.46 32.68
# BF, AETI, T respectivly of  L3 GEZ  2002 = Are 0.76 40.25 32.71
# BF, AETI, T respectivly of  L3 GEZ  2003 = Are 0.75 47.04 37.84
# BF, AETI, T respectivly of  L3 GEZ  2004 = Are 0.73 51.0 39.97
# BF, AETI, T respectivly of  L3 GEZ  2005 = Are 0.73 50.11 39.79
# BF, AETI, T respectivly of  L3 GEZ  2006 = Are 0.74 44.74 35.93
# BF, AETI, T respectivly of  L3 GEZ  2007 = Are 0.72 42.87 33.52
# BF, AETI, T respectivly of  L3 GEZ  2008 = Are 0.74 29.99 23.42
# BF, AETI, T respectivly of  L3 GEZ  2009 = Are 0.67 26.84 19.78
# BF, AETI, T respectivly of  L3 GEZ  2010 = Are 0.59 19.26 12.84
# BF, AETI, T respectivly of  L3 GEZ  2011 = Are 0.63 12.54 8.55
# BF, AETI, T respectivly of  L3 GEZ  2012 = Are 0.48 17.01 9.2
# BF, AETI, T respectivly of  L3 GEZ  2013 = Are 0.49 16.63 8.0
# BF, AETI, T respectivly of  L3 GEZ  2014 = Are 0.63 4.22 2.31
# BF, AETI, T respectivly of  L3 GEZ  2015 = Are 0.58 4.99 2.6
# BF, AETI, T respectivly of  L3 GEZ  2016 = Are 0.38 8.29 3.11
# BF, AETI, T respectivly of  L3 GEZ  2017 = Are 0.39 6.22 2.44
# BF, AETI, T respectivly of  L3 GEZ  2018 = Are 0.42 7.06 2.83
# BF, AETI, T respectivly of  L3 GEZ  2019 = Are 0.49 5.92 2.68
# BF, AETI, T respectivly of  L3 GEZ  2020 = Are 0.53 5.67 2.77
# BF, AETI, T respectivly of  L3 GEZ  2021 = Are 0.58 5.0 2.61
# BF, AETI, T respectivly of  L3 GEZ  2022 = Are 0.72 5.56 3.67
# BF, AETI, T respectivly of  L3 GEZ  2023 = Are 0.7 10.5 7.38
# BF, AETI, T respectivly of  L3 GEZ  2024 = Are 0.74 13.63 10.24
# BF, AETI, T respectivly of  L3 GEZ  2025 = Are 0.77 15.4 12.08
# BF, AETI, T respectivly of  L3 GEZ  2026 = Are 0.86 17.36 14.81
# BF, AETI, T respectivly of  L3 GEZ  2027 = Are 0.85 20.92 17.89
# BF, AETI, T respectivly of  L3 GEZ  2028 = Are 0.86 22.44 19.69
# BF, AETI, T respectivly of  L3 GEZ  2029 = Are 0.82 22.02 18.77
# BF, AETI, T respectivly of  L3 GEZ  2030 = Are 0.8 22.22 18.44
# BF, AETI, T respectivly of  L3 GEZ  2031 = Are 0.84 19.02 16.27
# BF, AETI, T respectivly of  L3 GEZ  2032 = Are 0.83 17.51 14.95
# BF, AETI, T respectivly of  L3 GEZ  2033 = Are 0.84 16.2 13.86
# BF, AETI, T respectivly of  L3 GEZ  2034 = Are 0.84 15.79 13.46
# BF, AETI, T respectivly of  L3 GEZ  2035 = Are 0.84 15.35 13.07
# BF, AETI, T respectivly of  L3 GEZ  2036 = Are 0.88 20.31 17.75
# BF, AETI, T respectivly of  L3 GEZ  2101 = Are 0.88 19.56 17.27
# BF, AETI, T respectivly of  L3 GEZ  2102 = Are 0.88 18.59 16.42
# BF, AETI, T respectivly of  L3 GEZ  2103 = Are 0.88 21.7 19.18
# BF, AETI, T respectivly of  L3 GEZ  2104 = Are 0.88 20.41 18.12
# BF, AETI, T respectivly of  L3 GEZ  2105 = Are 0.86 20.18 17.66
# BF, AETI, T respectivly of  L3 GEZ  2106 = Are 0.86 16.67 14.7
# BF, AETI, T respectivly of  L3 GEZ  2107 = Are 0.83 21.52 18.47
# BF, AETI, T respectivly of  L3 GEZ  2108 = Are 0.75 19.86 15.73
# BF, AETI, T respectivly of  L3 GEZ  2109 = Are 0.73 17.86 13.48
# BF, AETI, T respectivly of  L3 GEZ  2110 = Are 0.7 14.58 10.53
# BF, AETI, T respectivly of  L3 GEZ  2111 = Are 0.63 13.35 8.95
# BF, AETI, T respectivly of  L3 GEZ  2112 = Are 0.51 11.43 6.33
# BF, AETI, T respectivly of  L3 GEZ  2113 = Are 0.59 8.6 5.01
# BF, AETI, T respectivly of  L3 GEZ  2114 = Are 0.55 9.81 5.45
# BF, AETI, T respectivly of  L3 GEZ  2115 = Are 0.46 11.64 5.88
# BF, AETI, T respectivly of  L3 GEZ  2116 = Are 0.35 7.08 2.5
# BF, AETI, T respectivly of  L3 GEZ  2117 = Are 0.38 5.85 2.02

# %% [markdown]
# ## Step 3d - Calculate adequacy (relative evapotranspiration)
# $Adequacy= \frac{ET_a}{ET_p}$

# %%
## Calculate and save raster adequacy layer

# collecting Geoinfo such as projection, the x and y axis
in_fh = AETI_fhs[0]      
driver, NDV, xsize, ysize, GeoT, Projection = gis.GetGeoInfo(in_fh)
spatial_extent = (GeoT[0], GeoT[0] + GeoT[1] * xsize, GeoT[3] + GeoT[5] * ysize, GeoT[3])  # get spatial extent of raster

for ETfh, ETpfh in zip(AETI_fhs, ETp_fhs):
    AETI = gis.OpenAsArray(ETfh,  nan_values=True)
    for i in range(len(AETI_fhs)):
        AETI = gis.OpenAsArray(AETI_fhs[i], nan_values=True)
        AETI1_1D  = np.reshape(AETI,  AETI.shape[0]*AETI.shape[1])
        ETp = np.nanpercentile(AETI1_1D, 90)
        #ETp  = gis.OpenAsArray(ETpfh, nan_values=True)
        
        ETa_by_ETp = (AETI / ETp)*100
        
        ETa_by_ETp_mean = np.nanmean(ETa_by_ETp)
        # Identify the date from the file name
        date  = os.path.basename(ETfh).split('.')[0].replace('AETI', '').replace('_', ' ')
        
        #print ('Adequacy is', date, '=', round(ETa_by_ETp, 2))
    print ('Adequacy is', date, '=', ETa_by_ETp_mean) 
        
    # update the file name, and save into output folder
    #basename  = os.path.basename(ETfh).replace('AETI', 'Adequacy')
    #output_fn = os.path.join(output_folderAd, basename)
    #gis.CreateGeoTiff(output_fn, ETa_by_ETp, driver, NDV, xsize, ysize, GeoT, Projection) 
  
    # Plot the raster map
    #seasonal = ETa_by_ETp
    
    #plt.figure(figsize = (12,8))
    #plt.imshow(seasonal, cmap='RdYlGn', vmin=np.nanmin(seasonal), vmax=np.nanmax(seasonal), extent=spatial_extent)
    #plt.colorbar(shrink=0.75, label='Adequacy [-]')
    #plt.xlabel('Longitude ($^{\circ}$ East)', fontsize=12)  # add axes label
    #plt.ylabel('Latitude ($^{\circ}$ North)', fontsize=12)
    #plt.title('Adequacy [-] ' + date)
    #plt.show ()
    ;
# Out:
# Adequacy is L3 GEZ  2101 = 58.473164
# Adequacy is L3 GEZ  2102 = 58.473164
# Adequacy is L3 GEZ  2103 = 58.473164
# Adequacy is L3 GEZ  2104 = 58.473164
# Adequacy is L3 GEZ  2105 = 58.473164
# Adequacy is L3 GEZ  2106 = 58.473164

# %% [markdown]
# ## Step 3e - Calculate Relative water Deficit (RWD)
# $RWD= 1-\frac{ET_a}{ET_x}$
# <br/>${ET_x} = $ Can be ETp or 99 percentile of the actual evapotranspiration

# %%
# collecting Geoinfo such as projection, the x and y axis
in_fh = AETI_fhs[0]      
driver, NDV, xsize, ysize, GeoT, Projection = gis.GetGeoInfo(in_fh)
spatial_extent = (GeoT[0], GeoT[0] + GeoT[1] * xsize, GeoT[3] + GeoT[5] * ysize, GeoT[3])  # get spatial extent of raster
   
for i in range(len(AETI_fhs)):
    AETI = gis.OpenAsArray(AETI_fhs[i], nan_values=True)
    
    # reshape the arrays
    AETI1_1D  = np.reshape(AETI,  AETI.shape[0]*AETI.shape[1])
    ETx       = np.nanpercentile(AETI1_1D, 95)
    
    AETI_mean = np.nanmean(AETI)
   
    RWD = 1-(AETI_mean/ETx)
    
    # Identify the date from the file name
    date  = os.path.basename(AETI_fhs[i]).split('.')[0].replace('AETI', '').replace('_', ' ') 
    
    #print ('Relative water deficit', date, '=', round(RWD, 2))
    print ('AETI mean', date, '=', round(AETI_mean, 2))
# Out:
# AETI mean L3 GEZ  2101 = 19.56
# AETI mean L3 GEZ  2102 = 18.59
# AETI mean L3 GEZ  2103 = 21.7
# AETI mean L3 GEZ  2104 = 20.41
# AETI mean L3 GEZ  2105 = 20.18
# AETI mean L3 GEZ  2106 = 16.67
# AETI mean L3 GEZ  2107 = 21.52
# AETI mean L3 GEZ  2108 = 19.86
# AETI mean L3 GEZ  2109 = 17.86
# AETI mean L3 GEZ  2110 = 14.58
# AETI mean L3 GEZ  2111 = 13.35
# AETI mean L3 GEZ  2112 = 11.43
# AETI mean L3 GEZ  2113 = 8.6
# AETI mean L3 GEZ  2114 = 9.81
# AETI mean L3 GEZ  2115 = 11.64
# AETI mean L3 GEZ  2116 = 7.08
# AETI mean L3 GEZ  2117 = 5.85

# %% [markdown]
# ## Step 3f - Calculate Crop Water Dificit (CWD)
# * CWD = ET-ETp
# * ETp is the 95 percentile of the actual evapotranspiration

# %%
# collecting Geoinfo such as projection, the x and y axis
in_fh = AETI_fhs[0]      
driver, NDV, xsize, ysize, GeoT, Projection = gis.GetGeoInfo(in_fh)
spatial_extent = (GeoT[0], GeoT[0] + GeoT[1] * xsize, GeoT[3] + GeoT[5] * ysize, GeoT[3])  # get spatial extent of raster
  
for Tfh, ETfh in zip(T_fhs, AETI_fhs):
    T    = gis.OpenAsArray(Tfh,  nan_values=True)
    AETI = gis.OpenAsArray(ETfh, nan_values=True)
    AETI1_1D  = np.reshape(AETI,  AETI.shape[0]*AETI.shape[1])
    ETp = np.nanpercentile(AETI1_1D, 90)
    
    CWD = AETI-ETp
    CWD_mean = np.nanmean(CWD)
    
    # Identify the date from the file name
    date  = os.path.basename(ETfh).split('.')[0].replace('AETI', '').replace('_', ' ') 
    
    # update the file name, and save into output folder
    basename  = os.path.basename(ETfh).replace('AETI', 'CWD')  
    output_fn = os.path.join(output_folderCWD, basename)
    gis.CreateGeoTiff(output_fn, T_over_AETI, driver, NDV, xsize, ysize, GeoT, Projection) 
    
    # Plot the raster map
    seasonal = CWD
    
    plt.figure(figsize = (12,8))
    plt.imshow(seasonal, cmap='RdYlGn', vmin=np.nanmin(seasonal), vmax=np.nanmax(seasonal), extent=spatial_extent)
    plt.colorbar(shrink=0.75, label='CWD [mm/dekade]')
    plt.xlabel('Longitude ($^{\circ}$ East)', fontsize=14)  # add axes label
    plt.ylabel('Latitude ($^{\circ}$ North)', fontsize=14)
    plt.title('Crop Water Deficit [-] ' + date)
#     plt.clim(0,1)
    plt.show ()
    print ('Relative water deficit', date, '=', CWD_mean)
;

# %% [markdown]
# ## Step 3g - Calculate Reliablity
#
# * Temporal variation of ET/ETp
# * ETp is the 95 percentile of the actual evapotranspiration

# %% [markdown]
# ## Step 3h - Calculate Land Productivity
# * Y = AGBP/ET

# %% [markdown]
# ## Step 3i - Calculate WP
# * WP = Y/ET

# %% [markdown]
# ## Step 3j - Calculate Crop Water Productivity per Beneficial Water Consumption (WPBF)
# * WPBF = Y/T
